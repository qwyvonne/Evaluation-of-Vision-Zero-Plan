# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot

# %%
plu = pd.read_csv('C:/Users/qw508/OneDrive/Documents/Capstone/nyc_pluto_19v1_csv/pluto_19v1.csv')
# Out:
# C:\Users\qw508\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (16,17,18,20,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
crash = pd.read_csv('C:/Users/qw508/OneDrive/Documents/Capstone/NYPD_Motor_Vehicle_Collisions_-_Crashes.csv')
# Out:
# C:\Users\qw508\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
list(plu.columns)
# Out:
# ['borough',
#  'block',
#  'lot',
#  'cd',
#  'ct2010',
#  'cb2010',
#  'schooldist',
#  'council',
#  'zipcode',
#  'firecomp',
#  'policeprct',
#  'healtharea',
#  'sanitboro',
#  'sanitsub',
#  'address',
#  'zonedist1',
#  'zonedist2',
#  'zonedist3',
#  'zonedist4',
#  'overlay1',
#  'overlay2',
#  'spdist1',
#  'spdist2',
#  'spdist3',
#  'ltdheight',
#  'splitzone',
#  'bldgclass',
#  'landuse',
#  'easements',
#  'ownertype',
#  'ownername',
#  'lotarea',
#  'bldgarea',
#  'comarea',
#  'resarea',
#  'officearea',
#  'retailarea',
#  'garagearea',
#  'strgearea',
#  'factryarea',
#  'otherarea',
#  'areasource',
#  'numbldgs',
#  'numfloors',
#  'unitsres',
#  'unitstotal',
#  'lotfront',
#  'lotdepth',
#  'bldgfront',
#  'bldgdepth',
#  'ext',
#  'proxcode',
#  'irrlotcode',
#  'lottype',
#  'bsmtcode',
#  'assessland',
#  'assesstot',
#  'exempttot',
#  'yearbuilt',
#  'yearalter1',
#  'yearalter2',
#  'histdist',
#  'landmark',
#  'builtfar',
#  'residfar',
#  'commfar',
# ...

# %%
list(crash.columns)
# Out:
# ['DATE',
#  'TIME',
#  'BOROUGH',
#  'ZIP CODE',
#  'LATITUDE',
#  'LONGITUDE',
#  'LOCATION',
#  'ON STREET NAME',
#  'CROSS STREET NAME',
#  'OFF STREET NAME',
#  'NUMBER OF PERSONS INJURED',
#  'NUMBER OF PERSONS KILLED',
#  'NUMBER OF PEDESTRIANS INJURED',
#  'NUMBER OF PEDESTRIANS KILLED',
#  'NUMBER OF CYCLIST INJURED',
#  'NUMBER OF CYCLIST KILLED',
#  'NUMBER OF MOTORIST INJURED',
#  'NUMBER OF MOTORIST KILLED',
#  'CONTRIBUTING FACTOR VEHICLE 1',
#  'CONTRIBUTING FACTOR VEHICLE 2',
#  'CONTRIBUTING FACTOR VEHICLE 3',
#  'CONTRIBUTING FACTOR VEHICLE 4',
#  'CONTRIBUTING FACTOR VEHICLE 5',
#  'COLLISION_ID',
#  'VEHICLE TYPE CODE 1',
#  'VEHICLE TYPE CODE 2',
#  'VEHICLE TYPE CODE 3',
#  'VEHICLE TYPE CODE 4',
#  'VEHICLE TYPE CODE 5']

# %%
crash['NUMBER OF CYCLIST INJURED'].unique()
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %%
crash['NUMBER OF CYCLIST KILLED'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
crash['DATE'].unique()
# Out:
# array(['09/13/2019', '07/09/2019', '09/12/2019', ..., '07/02/2012',
#        '07/10/2012', '07/04/2012'], dtype=object)

# %%
crash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1569425 entries, 0 to 1569424
# Data columns (total 29 columns):
# DATE                             1569425 non-null object
# TIME                             1569425 non-null object
# BOROUGH                          1095377 non-null object
# ZIP CODE                         1095190 non-null object
# LATITUDE                         1376164 non-null float64
# LONGITUDE                        1376164 non-null float64
# LOCATION                         1376164 non-null object
# ON STREET NAME                   1263339 non-null object
# CROSS STREET NAME                1050365 non-null object
# OFF STREET NAME                  213923 non-null object
# NUMBER OF PERSONS INJURED        1569408 non-null float64
# NUMBER OF PERSONS KILLED         1569394 non-null float64
# NUMBER OF PEDESTRIANS INJURED    1569425 non-null int64
# NUMBER OF PEDESTRIANS KILLED     1569425 non-null int64
# ...

# %%
df = df[df['Borough'].isin(['QUEENS', 'BRONX', 'MANHATTAN', 'BROOKLYN',
       'STATEN ISLAND'])]

# %%
#Find all cases with injury or killed 
crash.groupby('NUMBER OF CYCLIST INJURED').count()
# Out:
#                               DATE     TIME  BOROUGH  ZIP CODE  LATITUDE  \
# NUMBER OF CYCLIST INJURED
# 0                          1537096  1537096  1069430   1069243   1346486
# 1                            32086    32086    25777     25777     29474
# 2                              232      232      164       164       197
# 3                               10       10        5         5         6
# 4                                1        1        1         1         1
#
#                            LONGITUDE  LOCATION  ON STREET NAME  \
# NUMBER OF CYCLIST INJURED
# 0                            1346486   1346486         1235075
# 1                              29474     29474           28068
# 2                                197       197             187
# 3                                  6         6               8
# 4                                  1         1               1
#
#                            CROSS STREET NAME  OFF STREET NAME  ...  \
# ...

# %%
crash.groupby('DATE').count()[['COLLISION_ID']].plot(alpha=.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-fbe36c220715> in <module>
#       1 crash.groupby('DATE').count()[['COLLISION_ID']].plot(alpha=.7)
# ----> 2 plt.ylabel('crashes per day',fontsize=20)
#       3 plt.title('Police Reported')
#
# NameError: name 'plt' is not defined

# %%
df_complaint = df.groupby('Complaint Type').count()

# %%
df_complaint['Location']
# Out:
# Complaint Type
# Street Light Condition      515165
# Traffic Signal Condition    242313
# Name: Location, dtype: int64

# %%
df_cause = pd.DataFrame({'Number of Service Request Received':df_complaint['Unique Key'],
                         'Number of Incidents Location Recorded': df_complaint['Location']
                        })
ax = df_cause.plot.bar(rot=0)

# %%
df_borough = df.groupby('Borough').count()

# %%
df_borough
# Out:
#                Unique Key  Created Date  Closed Date  Agency  Agency Name  \
# Borough
# BRONX              234399        234399       233845  234399       234399
# BROOKLYN           384187        384187       382941  384187       384187
# MANHATTAN          209838        209838       209025  209838       209838
# QUEENS             395311        395311       393965  395311       395311
# STATEN ISLAND       76536         76536        76206   76536        76536
#
#                Complaint Type  Descriptor  Location Type  Incident Zip  \
# Borough
# BRONX                  234399      234395              0         96812
# BROOKLYN               384187      384183              0        259740
# MANHATTAN              209838      209821              0         34023
# QUEENS                 395311      395306              0        290380
# STATEN ISLAND           76536       76534              0         76533
#
# ...

# %%
df_cause = pd.DataFrame({'Number of Service Request Received':df_borough['Unique Key'],
                         'Number of Incidents Location Recorded': df_borough['Location']
                        })
ax = df_cause.plot.bar(rot=0)

# %%
df
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 0          24764818  01/10/2013 11:19:00 AM  01/10/2013 11:19:00 AM    DOT
# 1          24764808  01/10/2013 01:22:00 PM  01/10/2013 01:22:00 PM    DOT
# 3          24764766  01/10/2013 09:12:00 AM  01/09/2013 01:20:00 AM    DOT
# 4          24764811  01/10/2013 10:33:00 PM  01/16/2013 02:45:00 AM    DOT
# 5          24765545  01/11/2013 11:23:00 AM  01/11/2013 11:23:00 AM    DOT
# 6          34689708  11/02/2016 09:15:00 PM  11/10/2016 12:05:00 AM    DOT
# 7          24764828  01/10/2013 02:29:00 PM  01/09/2013 02:28:00 PM    DOT
# 8          24765535  01/11/2013 10:45:00 AM  01/10/2013 01:10:00 AM    DOT
# 9          24765566  01/11/2013 01:20:00 PM  01/11/2013 01:20:00 PM    DOT
# 10         24765588  01/11/2013 09:00:00 PM  01/11/2013 10:10:00 PM    DOT
# 11         24765552  01/11/2013 11:10:00 AM  01/11/2013 11:10:00 AM    DOT
# ...
